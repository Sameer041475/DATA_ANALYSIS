# %% [markdown]
# # Day - 2

# %% [markdown]
# # Feacture Engineering

# %%
import pandas as pd

# %%
df = pd.read_csv("ball_by_ball_ipl.csv")
df
# Out:
#         Unnamed: 0  Match ID        Date                               Venue  \
# 0                0   1359507  2023-04-23                        Eden Gardens
# 1                1   1359507  2023-04-23                        Eden Gardens
# 2                2   1359507  2023-04-23                        Eden Gardens
# 3                3   1359507  2023-04-23                        Eden Gardens
# 4                4   1359507  2023-04-23                        Eden Gardens
# ...            ...       ...         ...                                 ...
# 239688      239688   1136596  2018-05-05  Rajiv Gandhi International Stadium
# 239689      239689   1136596  2018-05-05  Rajiv Gandhi International Stadium
# 239690      239690   1136596  2018-05-05  Rajiv Gandhi International Stadium
# 239691      239691   1136596  2018-05-05  Rajiv Gandhi International Stadium
# 239692      239692   1136596  2018-05-05  Rajiv Gandhi International Stadium
#
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                   int64
# Match ID                     int64
# Date                        object
# Venue                       object
# Bat First                   object
# Bat Second                  object
# Innings                      int64
# Over                         int64
# Ball                         int64
# Batter                      object
# Non Striker                 object
# Bowler                      object
# Batter Runs                  int64
# Extra Runs                   int64
# Runs From Ball               int64
# Ball Rebowled                int64
# Extra Type                  object
# Wicket                       int64
# Method                      object
# Player Out                  object
# Innings Runs                 int64
# Innings Wickets              int64
# Target Score                 int64
# Runs to Get                float64
# Balls Remaining              int64
# Winner                      object
# Chased Successfully          int64
# ...

# %%
pd.to_datetime(df['Date']).dt.year
# Out:
# 0         2023
# 1         2023
# 2         2023
# 3         2023
# 4         2023
#           ...
# 239688    2018
# 239689    2018
# 239690    2018
# 239691    2018
# 239692    2018
# Name: Date, Length: 239693, dtype: int32

# %%
pd.to_datetime(df['Date']).dt.month
# Out:
# 0         4
# 1         4
# 2         4
# 3         4
# 4         4
#          ..
# 239688    5
# 239689    5
# 239690    5
# 239691    5
# 239692    5
# Name: Date, Length: 239693, dtype: int32

# %%
pd.to_datetime(df['Date']).dt.date
# Out:
# 0         2023-04-23
# 1         2023-04-23
# 2         2023-04-23
# 3         2023-04-23
# 4         2023-04-23
#              ...
# 239688    2018-05-05
# 239689    2018-05-05
# 239690    2018-05-05
# 239691    2018-05-05
# 239692    2018-05-05
# Name: Date, Length: 239693, dtype: object

# %%
df['Batter Runs']
# Out:
# 0         4
# 1         0
# 2         0
# 3         0
# 4         1
#          ..
# 239688    2
# 239689    6
# 239690    4
# 239691    1
# 239692    1
# Name: Batter Runs, Length: 239693, dtype: int64

# %%
df['Method'].unique()
# Out:
# array([nan, 'bowled', 'caught', 'lbw', 'stumped', 'run out',
#        'caught and bowled', 'retired hurt', 'hit wicket', 'retired out',
#        'obstructing the field'], dtype=object)

# %%
valid_methods = ['bowled','caught','lbw','stumped','catch and bowled','hit wicket']
df['bowler_wickets'] = df['Method'].isin(valid_methods).astype(int)

# %% [markdown]
# # Feacture Selection

# %% [raw]
# future selection is the process of choosing the most
# important feactures from youur data . it helps to identify the
# most relevant variables , making data analysis more efficient ,
# interpretable ,and insightful.

# %% [markdown]
# # Feacture Transformation

# %% [raw]
# it is the process of modifying or converting
# existiong feactures into a new format to improve how well
# your ML model can understand the data.
